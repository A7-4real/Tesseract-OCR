# %% [markdown]
# ## Tesseract OCR

# %%
from PIL import Image

# %%
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract'

# %%
# TEST IMAGE 1 - (source - twitter)

# %%
Image.open("C:/Users/colak/Desktop/twitter-thumb-test-image.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=815x458 at 0x1BB400F8308>

# %%
# simple image to string
print(pytesseract.image_to_string(Image.open("C:/Users/colak/Desktop/twitter-thumb-test-image.jpg")))
print("done")
# Out:
# Twe
#
# Twitter @
# @Twitter
#
# hello literally everyone
#
# 1:27 PM - Oct 4, 2021 - Sprinkir
#
# 335.6K Retweets 117.8K Quote Tweets 1.6M Likes
#
# 2 uD Lo)
#
#
# done

# %%
# TEST IMAGE 2 (source - Boomlive.in)

# %%
Image.open("C:/Users/colak/Desktop/974058-putin-02-ocr-test-2.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x768 at 0x1BB400E8F08>

# %%
print(pytesseract.image_to_string(Image.open("C:/Users/colak/Desktop/974058-putin-02-ocr-test-2.jpg")))
# Out:
# Pakistan is just a Cemetery for
# Pakistanis
#
# Russian President
#
# Hyder Abbasi
# 15 March at 22:18-@
#
# RUSSIAN PRESIDENT, Vladimir Putin Says:
# Pakistan Is A Cemetery For Pakistani’s:
#
# "When a Pakistani becomes rich, his bank
# accounts are in Switzerland. He travels to
# London/ America for Medical treatment.
#
# He invests in Uk/ Dubai. He buys from Dubai. He
# consumes Chinese. He prays in Rome or Mecca.
# His children study in Europe. He travels to
# Canada, USA, Europe for tourism.
#
# If he die, he will be buried in his native country of
# Pakistan.
#
# Pakistan is just a cemetery for Pakistani’s. How
# could a cemetery be developed?" See less

# %%
# this works great!!
